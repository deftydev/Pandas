# %%
import pandas as pd

# %%
pd.read_csv('test.csv').head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
pd.read_csv('test.csv').tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
dataframe=pd.read_csv("test.csv")
dataframe.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
type(dataframe["Utilities"])
# Out:
# pandas.core.series.Series

# %%
dataframe[['MiscVal',"YrSold"]]
# Out:
#       MiscVal  YrSold
# 0           0    2010
# 1       12500    2010
# 2           0    2010
# 3           0    2010
# 4           0    2010
# ...       ...     ...
# 1454        0    2006
# 1455        0    2006
# 1456        0    2006
# 1457      700    2006
# 1458        0    2006
#
# [1459 rows x 2 columns]

# %%
type(dataframe[['MiscVal',"YrSold"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Read html

# %%
df=pd.read_html("https://stats.espncricinfo.com/ci/content/records/335432.html")

# %%
len(df)
# Out:
# 3

# %%
df[0]
# Out:
#                               Series/Tournament        Season  Unnamed: 2  \
# 0                England in Australia ODI Match       1970/71         NaN
# 1      Prudential Trophy (Australia in England)          1972         NaN
# 2             Pakistan in New Zealand ODI Match       1972/73         NaN
# 3    Prudential Trophy (New Zealand in England)          1973         NaN
# 4    Prudential Trophy (West Indies in England)          1973         NaN
# ..                                          ...           ...         ...
# 904    ICC Men's Cricket World Cup Super League  2020-2022/23         NaN
# 905          New Zealand in Pakistan ODI Series       2022/23         NaN
# 906               Sri Lanka in India ODI Series       2022/23         NaN
# 907              Ireland in Zimbabwe ODI Series       2022/23         NaN
# 908             New Zealand in India ODI Series       2022/23         NaN
#
#           Winner   Margin
# 0      Australia  1-0 (1)
# ...

# %%
df[0]["Series/Tournament"].head()
# Out:
# 0                England in Australia ODI Match
# 1      Prudential Trophy (Australia in England)
# 2             Pakistan in New Zealand ODI Match
# 3    Prudential Trophy (New Zealand in England)
# 4    Prudential Trophy (West Indies in England)
# Name: Series/Tournament, dtype: object

# %%
df[0].to_csv("series.csv") ##directly add this data to a csv file

# %% [markdown]
# # How to directly take data available on internet or github take the Raw url from github and copy here

# %%
df2=pd.read_excel("https://raw.githubusercontent.com/shadsluiter/ExcelExamples/master/Cell%20Phone%20Plans%20compared2.xlsx")

# %% [markdown]
# # JSON

# %%
import json
# json object only accept string, byte or bytearray
json_data= """{"name":"dev","phone":"1234","age":"21","address":["shatabdi nagar","panchvati enclave"]}"""

type(json_data)
# Out:
# str

# %%
loading=json.loads(json_data)    ##converts string, byte data into json format

loading
# Out:
# {'name': 'dev',
#  'phone': '1234',
#  'age': '21',
#  'address': ['shatabdi nagar', 'panchvati enclave']}

# %%
pd.DataFrame(loading)
# Out:
#   name phone age            address
# 0  dev  1234  21     shatabdi nagar
# 1  dev  1234  21  panchvati enclave

# %% [markdown]
# # Example 2

# %%
json_data1= """{"name":"dev","phone":"1234","age":"21","address":["shatabdi nagar","panchvati enclave"],"course":[]}"""

type(json_data1)
# Out:
# str

# %%
loading1=json.loads(json_data1)

loading1
# Out:
# {'name': 'dev',
#  'phone': '1234',
#  'age': '21',
#  'address': ['shatabdi nagar', 'panchvati enclave'],
#  'course': []}

# %%
pd.DataFrame(loading1) ##it will generate value erroras last column do not have any data so you have to look for this whenevr anybody sends you a json data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7196\2111841294.py in <module>
# ----> 1 pd.DataFrame(loading1) ##it will generate value erroras last column do not have any data so you have to look for this whenevr anybody sends you a json data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
del loading1['course']

# %%
pd.DataFrame(loading1)
# Out:
#   name phone age            address
# 0  dev  1234  21     shatabdi nagar
# 1  dev  1234  21  panchvati enclave

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

dff= pd.read_json(url)

# %%
dff.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %% [markdown]
# # But if you want to have raw data from the internet so for that you should use requests

# %%
import requests

data=requests.get(url)

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#   'id': 1552789803,
#   'node_id': 'PR_kwDOAA0YD85IT4w7',
#   'number': 50938,
#   'title': 'Resolved duplicate issue by updating obj object',
#   'user': {'login': 'asadullahnaeem',
#    'id': 48176260,
#    'node_id': 'MDQ6VXNlcjQ4MTc2MjYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48176260?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/asadullahnaeem',
#    'html_url': 'https://github.com/asadullahnaeem',
# ...

# %%
len(data1)  ##numer of unique dictionaries
# Out:
# 30

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50938/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/50938',
#  'id': 1552789803,
#  'node_id': 'PR_kwDOAA0YD85IT4w7',
#  'number': 50938,
#  'title': 'Resolved duplicate issue by updating obj object',
#  'user': {'login': 'asadullahnaeem',
#   'id': 48176260,
#   'node_id': 'MDQ6VXNlcjQ4MTc2MjYw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/48176260?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/asadullahnaeem',
#   'html_url': 'https://github.com/asadullahnaeem',
# ...

# %%
data1[0]['user']['id']
# Out:
# 48176260

# %%
df=pd.DataFrame(data1)

# %%
df.tail(2)
# Out:
#                                                   url  \
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            html_url          id  \
# 28  https://github.com/pandas-dev/pandas/pull/50902  1551387562
# ...

# %%
df_get_specific_column=pd.DataFrame(data1, columns=['url','repository_url'])

# %%
df_get_specific_column.tail(6)
# Out:
#                                                   url  \
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas

# %%
df_get_user_column=pd.DataFrame(data1, columns=['user'])
df_get_user_column
# Out:
#                                                  user
# 0   {'login': 'asadullahnaeem', 'id': 48176260, 'n...
# 1   {'login': 'bsdfan', 'id': 1309101, 'node_id': ...
# 2   {'login': 'anushkabishnoi', 'id': 97040192, 'n...
# 3   {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 4   {'login': 'daureg', 'id': 19685, 'node_id': 'M...
# 5   {'login': 'topper-123', 'id': 26364415, 'node_...
# 6   {'login': 'topper-123', 'id': 26364415, 'node_...
# 7   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 8   {'login': 'partev', 'id': 23830955, 'node_id':...
# 9   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 11  {'login': 'topper-123', 'id': 26364415, 'node_...
# 12  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 13  {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 14  {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 15  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# ...

# %%
for i in df_get_user_column:
    df=pd.DataFrame(i)
    
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15744\1566751531.py in <module>
#       1 for i in df_get_user_column:
# ----> 2     df=pd.DataFrame(i)
#       3
#       4 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
for i,j in df_get_user_column.items():
    print(j[0]['login'])
# Out:
# asadullahnaeem

# %%
# df_expand_user_column= pd.DataFrame(df_get_user_column, columns=["login","id","node_id","avatar_url","avatar_url",
#       "gravatar_id",
#       "url",
#       "html_url",
#       "followers_url",
#       "following_url",
#       "gists_url",
#       "starred_url",
#       "subscriptions_url",
#       "organizations_url",
#       "repos_url",
#       "events_url",
#       "received_events_url",
#       "type" ,
#       "site_admin"])

# %%
df_expand_user_column= pd.DataFrame(df_get_user_column)

# %%
df_expand_user_column
# Out:
#                                                  user
# 0   {'login': 'bsdfan', 'id': 1309101, 'node_id': ...
# 1   {'login': 'anushkabishnoi', 'id': 97040192, 'n...
# 2   {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 3   {'login': 'daureg', 'id': 19685, 'node_id': 'M...
# 4   {'login': 'topper-123', 'id': 26364415, 'node_...
# 5   {'login': 'topper-123', 'id': 26364415, 'node_...
# 6   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 7   {'login': 'partev', 'id': 23830955, 'node_id':...
# 8   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 10  {'login': 'topper-123', 'id': 26364415, 'node_...
# 11  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 12  {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 13  {'login': 'Hexx333', 'id': 116751160, 'node_id...
# 14  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 15  {'login': 'Hexx333', 'id': 116751160, 'node_id...
# ...
