# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(1000) , index=pd.date_range('2023/01/27', periods=1000))
df
# Out:
#                    0
# 2023-01-27  1.166462
# 2023-01-28  0.361338
# 2023-01-29 -1.526624
# 2023-01-30  1.843196
# 2023-01-31  0.352233
# ...              ...
# 2025-10-18 -1.530587
# 2025-10-19  0.837811
# 2025-10-20  1.457180
# 2025-10-21 -0.157842
# 2025-10-22  0.692014
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df= pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11,].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')  ##t displays frequency of the dataset
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Plot a histogram for every column available in a dataset with color red.

# %%
df.hist(figsize=(20,10),color='r')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='g' , alpha=0.6)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# # BOXPLOT

# %%
df.plot(kind='box',color={'boxes':'r','whiskers':'b'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatter Plot

# %%
df.plot.scatter(x='sepal_length' , y ='petal_length', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length' , y ='petal_length', c='sepal_width',s=df['petal_width']*100) ##s for sixe of the dot will be determined by petal_width
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Pie chart displays portion of the dataset but remember first you have to remove categorical variables

# %%
df2=df.iloc[0]
del df2['species']
df2.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %% [markdown]
# # Plotly is the best library to plot graphs

# %%
df2
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.iplot()
# Out:
# <div>                            <div id="84e30850-ecde-4277-9812-0971ef5f5fe9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length' , y ='sepal_width', mode='markers')  ##similar to scatter plot
# Out:
# <div>                            <div id="1adb4f5f-1e3b-4ad9-9a33-353505525f90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers')
# Out:
# <div>                            <div id="f45a48f5-a335-4ff1-8d13-6570f27cb3bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='sepal_length' , y ='sepal_width',size='petal_width')
# Out:
# <div>                            <div id="a7c446ca-1501-4a9c-8db7-f3d31c97abeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="954ba8b6-a390-4ee4-9c74-79c9e1796303" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='scatter3d',x='sepal_length' , y ='sepal_width',z='petal_width')
# Out:
# <div>                            <div id="58fef097-6963-4622-acec-7d32239e366f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind='bubble3d',x='sepal_length' , y ='sepal_width',z='petal_width',size='petal_length')

# %% [markdown]
# # plotly is the best one as you can see yur graph in real time on their website

# %%
import seaborn as sns

# %%
df=pd.read_csv('tips.csv')

# %%
sns.relplot(x='total_bill',y='tip',data=df, hue='smoker')  ##relational plot

# %%
sns.scatterplot(x=df.sepal_length,y=df.sepal_width)

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
#pandas inbuilt plot method, which ou can use on any DataFrame object

df.iloc[0,[1,2,3,4]].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['SepalLengthCm'].plot.hist()  ##it displays what is the number of values falling in range of 4 to 5 to 6
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d= df.iloc[0,[1,2,3,4]].plot.pie()  ##pie plot determines what is the percentage of value is taken by each column in one row of the dtaaset

# %%
a= d.get_figure()
a.savefig('test_pie.png')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1EFB-0158
#
#  Directory of C:\Users\user\Desktop\python
#
# 02/05/2023  01:35 PM    <DIR>          .
# 02/05/2023  01:35 PM    <DIR>          ..
# 02/03/2023  07:29 PM    <DIR>          .ipynb_checkpoints
# 08/03/2022  04:29 PM         3,167,083 28thmay-20220803T105916Z-001.zip
# 02/01/2023  11:22 AM    <DIR>          5-Days-Live-EDA-and-Feature-Engineering-main
# 01/31/2023  12:11 PM    <DIR>          7thmay
# 02/04/2023  07:54 PM            16,085 Admission_Prediction.csv
# 02/03/2023  02:57 PM             4,062 adv.xlsx.csv
# 01/03/2023  11:22 AM                60 data_2
# 01/15/2023  10:42 PM             2,342 data_science.txt
# 01/15/2023  10:42 PM               202 data_science2.txt
# 01/30/2023  07:51 PM         1,574,541 EDA- Part 1.ipynb
# 01/31/2023  11:27 AM         2,402,726 EDA.ipynb
# 01/31/2023  12:16 PM           272,432 Feature Engineering.ipynb
# 02/05/2023  01:35 PM         1,108,324 Graphs.ipynb
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.plot.scatter(x='SepalLengthCm' , y ='PetalLengthCm', c='SepalWidthCm',s=df['PetalWidthCm']*100) ##s for sixe of the dot will be determined by petal_width
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df['text'] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df['long'],
        lat = df['lat'],
        text = df['text'],
        mode = 'markers',
        marker_color = df['cnt'],
        ))

fig.update_layout(
        title = 'Most trafficked US airports<br>(Hover for airport names)',
        geo_scope='usa',
    )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# ...
